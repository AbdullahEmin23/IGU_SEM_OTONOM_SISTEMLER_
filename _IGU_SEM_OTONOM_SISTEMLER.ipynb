# %% [markdown]
# 16.12.2025 İGÜ SEM OTONOM EĞİTİMİ
#
#   ABDULLAH EMİN BAYRAM
#
#   GOOGLE COLAP DENEME 1

# %%
import os
os.chdir('/content/drive/My Drive/_IGU_SEM_OTONOM_SISTEMLER')
# !pwd
# Out:
# /content/drive/My Drive/_IGU_SEM_OTONOM_SISTEMLER
